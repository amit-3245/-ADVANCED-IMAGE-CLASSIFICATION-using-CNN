# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-3245/-ADVANCED-IMAGE-CLASSIFICATION-using-CNN/blob/main/audiototext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome in google colab")

# %%
# !pip install openai-whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 11.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 7.7 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803980 sha256=f6acf1fdd064dd8122098479ec83ad229bf3fa2cd044e0ba9823a2d7af8a1e32
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# ...

# %%
#use for install in system(apt)
# !apt-get install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.

# %%
# Install Whisper

# !pip install openai-whisper
# !pip install transformers

# Import Libraries

import whisper
from google.colab import files
from transformers import pipeline

# Load Whisper Model

model = whisper.load_model("base")

# Upload Audio File

print("Upload your audio file")
uploaded = files.upload()

# Get uploaded file name

audio_file = list(uploaded.keys())[0]

# Transcribe Audio

result = model.transcribe(audio_file)

# Extract text

transcribed_text = result["text"]

print("\nTranscribed Text:")
print(transcribed_text)

# Sentiment Analysis

sentiment_analyzer = pipeline("sentiment-analysis")

sentiment_result = sentiment_analyzer(transcribed_text)

print("\nSentiment Analysis Result:")
print(sentiment_result)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 16.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 5.9 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=303243c479b2ccbc9cfc63a8b87af8290f51f9938eae611f590046bcb524e1bd
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# ...
# 100%|████████████████████████████████████████| 139M/139M [00:01<00:00, 109MiB/s]
# Upload your audio file
#      <input type="file" id="files-fa0706b4-f1cf-4f05-9a3b-64aabb4fa772" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa0706b4-f1cf-4f05-9a3b-64aabb4fa772">
# ...
